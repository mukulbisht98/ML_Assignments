# %%
import numpy as np

# %%
# Question 1

a1 = np.random.rand(10,1)
print(np.mean(a1))
# Out:
# 0.3941446685025232

# %%
# Question - 2

a2 = np.random.rand(20,1)
print(np.var(a2))
print(np.std(a2))
# Out:
# 0.07531809216987029
# 0.27444141846643755

# %%
# Question 3

A = np.random.rand(10,20)
B = np.random.rand(20,25)
C = np.matmul(A, B)
print(C)
print(C.sum())
# Out:
# [[7.25994092 5.93097834 5.17063883 7.0078953  5.66409664 5.55461329
#   4.03745688 4.95565881 5.20749047 6.78913792 4.8560916  4.81903156
#   6.42330358 6.07832053 6.91863363 5.30543231 5.22581726 4.77194738
#   5.17316242 3.83650318 7.00522939 6.20615927 5.03203486 5.99219388
#   6.47965169]
#  [5.76380557 4.73396479 4.53007206 6.33471139 5.37668748 5.7531679
#   4.39767777 4.24683908 3.82615154 5.06100623 4.99461161 4.21482156
#   6.11409388 5.60412965 5.95979906 4.7048049  5.1067669  4.87772808
#   4.15317089 3.31075314 5.5230684  4.01766341 4.54957876 5.66091558
#   5.99422386]
#  [6.58199891 5.47634118 4.87342119 7.16911966 6.06204702 6.13812957
#   4.44346961 5.09371428 4.48461767 6.07835573 5.14422053 4.72695889
#   6.32668372 5.69605229 7.54180724 4.53906935 6.09450841 4.79412059
#   5.24098239 4.31166926 6.49736321 5.22621889 4.61245288 6.54561776
#   6.45083   ]
#  [4.91153337 4.35870896 4.4015607  5.40897678 4.92164574 5.7092688
# ...

# %%
# Question 4

def f(x):
    return 1 / (1 + np.exp(-x))

x = np.random.rand(10,1)
print(f(x))
# Out:
# [[0.65525266]
#  [0.62175668]
#  [0.59022921]
#  [0.64250891]
#  [0.68532662]
#  [0.66173071]
#  [0.61898396]
#  [0.5491396 ]
#  [0.71743525]
#  [0.53772806]]
