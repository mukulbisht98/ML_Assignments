# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Question 1

day = pd.read_csv('Bike-Sharing-Dataset/day.csv')
hour = pd.read_csv('Bike-Sharing-Dataset/hour.csv')

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day.shape
# Out:
# (731, 16)

# %%
day.size
# Out:
# 11696

# %%
list(day.columns)
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
day.describe(include='all')
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2012-11-28         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
hour.shape
# Out:
# (17379, 17)

# %%
hour.size
# Out:
# 295443

# %%
list(hour.columns)
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
hour.describe(include='all')
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-10-21           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %%
# Question 2

day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Question 3


plt.hist(x='instant' ,data=day,bins=80)
plt.grid()
plt.title('Count plot of instant in day')
# Out:
# Text(0.5, 1.0, 'Count plot of instant in day')

# %%
plt.hist(x='instant' ,data=hour,bins=80)
plt.grid()
plt.title('Count plot of instant in day')
# Out:
# Text(0.5, 1.0, 'Count plot of instant in day')

# %%
plt.hist(x='season' ,data=day,bins=50)
plt.grid()
plt.title('Count plot of season in day')
# Out:
# Text(0.5, 1.0, 'Count plot of season in day')

# %%
plt.hist(x='season' ,data=hour,bins=50)
plt.grid()
plt.title('Count plot of season in day')
# Out:
# Text(0.5, 1.0, 'Count plot of season in day')

# %%
plt.hist(x='temp' ,data=day,bins=50)
plt.grid()
plt.title('Count plot of temp in day')
# Out:
# Text(0.5, 1.0, 'Count plot of temp in day')

# %%
plt.hist(x='temp' ,data=hour,bins=50)
plt.grid()
plt.title('Count plot of temp in day')
# Out:
# Text(0.5, 1.0, 'Count plot of temp in day')

# %%
plt.hist(x='windspead' ,data=day,bins=50)
plt.grid()
plt.title('Count plot of windspead in day')
# Out:
# Text(0.5, 1.0, 'Count plot of windspead in day')

# %%
plt.hist(x='windspead' ,data=hour,bins=50)
plt.grid()
plt.title('Count plot of windspead in day')
# Out:
# Text(0.5, 1.0, 'Count plot of windspead in day')

# %%
sns.distplot(day['casual'])
plt.title("casual ")
plt.show()
# Out:
# C:\Users\Mukul\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(hour['casual'])
plt.title("casual ")
plt.show()

# %%
sns.distplot(day['registered' ])
plt.title("registered")
plt.show()

# %%
sns.distplot(hour['registered' ])
plt.title("registered")
plt.show()

# %%
sns.distplot(day['weathersit' ])
plt.title("weathersit")
plt.show()

# %%
sns.distplot(hour['weathersit' ])
plt.title("weathersit")
plt.show()

# %%
plt.hist(day['workingday'],bins=10 )
plt.title('working day')
plt.xlabel('work')
plt.ylabel('day')
# Out:
# Text(0, 0.5, 'day')

# %%
plt.hist(hour['workingday'],bins=10 )
plt.title('working day')
plt.xlabel('work')
plt.ylabel('day')
# Out:
# Text(0, 0.5, 'day')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(day.corr(),annot=True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(hour.corr(),annot=True)
